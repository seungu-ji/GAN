# %%
cd /content/drive/MyDrive/pytorch-GAN/CGAN
# Out:
# /content/drive/MyDrive/pytorch-GAN/CGAN

# %%
ls
# Out:
# CGAN.py  data_loader.py  train.py  Untitled0.ipynb  util.py

# %%
# !python3 train.py
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# TRAIN: EPOCH 0010 / 0020 | BATCH 0159 / 0469 | GEN 0.3767 | DISC REAL: 0.2212 | DISC FAKE: 0.2084
# TRAIN: EPOCH 0010 / 0020 | BATCH 0160 / 0469 | GEN 0.3759 | DISC REAL: 0.2211 | DISC FAKE: 0.2088
# TRAIN: EPOCH 0010 / 0020 | BATCH 0161 / 0469 | GEN 0.3752 | DISC REAL: 0.2212 | DISC FAKE: 0.2093
# TRAIN: EPOCH 0010 / 0020 | BATCH 0162 / 0469 | GEN 0.3744 | DISC REAL: 0.2213 | DISC FAKE: 0.2097
# TRAIN: EPOCH 0010 / 0020 | BATCH 0163 / 0469 | GEN 0.3740 | DISC REAL: 0.2213 | DISC FAKE: 0.2099
# TRAIN: EPOCH 0010 / 0020 | BATCH 0164 / 0469 | GEN 0.3743 | DISC REAL: 0.2210 | DISC FAKE: 0.2097
# TRAIN: EPOCH 0010 / 0020 | BATCH 0165 / 0469 | GEN 0.3751 | DISC REAL: 0.2211 | DISC FAKE: 0.2091
# TRAIN: EPOCH 0010 / 0020 | BATCH 0166 / 0469 | GEN 0.3755 | DISC REAL: 0.2207 | DISC FAKE: 0.2088
# TRAIN: EPOCH 0010 / 0020 | BATCH 0167 / 0469 | GEN 0.3756 | DISC REAL: 0.2204 | DISC FAKE: 0.2085
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
 
img = mpimg.imread('./result/train/png/9371_output.png')

plt.imshow(img)
plt.show()
