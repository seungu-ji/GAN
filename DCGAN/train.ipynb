# %% [markdown]
# celeba dataset 압축 해제

# %%
# !unzip -uq "/content/drive/MyDrive/data/img_align_celeba.zip" -d "/content/drive/MyDrive/data"

# %%
cd /content/drive/MyDrive/pytorch-GAN/DCGAN
# Out:
# /content/drive/MyDrive/pytorch-GAN/DCGAN

# %%
ls
# Out:
# data_loader.py  DCGAN.py  train.py  util.py

# %%
# !python3 train.py --data_dir '/content/drive/MyDrive/data/img_align_celeba'
# Out:
# 2021-01-30 12:59:17.788018: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# TRAIN: EPOCH 0001 / 0005 | BATCH 0001 / 0129 | GEN 3.0617 | DISC REAL: 1.0417 | DISC FAKE: 0.6858
# TRAIN: EPOCH 0001 / 0005 | BATCH 0002 / 0129 | GEN 3.8897 | DISC REAL: 0.5426 | DISC FAKE: 1.4345
# TRAIN: EPOCH 0001 / 0005 | BATCH 0003 / 0129 | GEN 4.7276 | DISC REAL: 0.4219 | DISC FAKE: 1.2178
# TRAIN: EPOCH 0001 / 0005 | BATCH 0004 / 0129 | GEN 5.1179 | DISC REAL: 0.4045 | DISC FAKE: 0.9993
# TRAIN: EPOCH 0001 / 0005 | BATCH 0005 / 0129 | GEN 5.4628 | DISC REAL: 0.3767 | DISC FAKE: 0.8735
# TRAIN: EPOCH 0001 / 0005 | BATCH 0006 / 0129 | GEN 5.8392 | DISC REAL: 0.3599 | DISC FAKE: 0.7763
# TRAIN: EPOCH 0001 / 0005 | BATCH 0007 / 0129 | GEN 6.1389 | DISC REAL: 0.3307 | DISC FAKE: 0.6888
# TRAIN: EPOCH 0001 / 0005 | BATCH 0008 / 0129 | GEN 6.4273 | DISC REAL: 0.3193 | DISC FAKE: 0.6300
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
 
img = mpimg.imread('./result/train/png/0020_output.png')

plt.imshow(img)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
 
img = mpimg.imread('./result/train/png/0249_output.png')

plt.imshow(img)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
 
img = mpimg.imread('./result/train/png/0636_output.png')

plt.imshow(img)
plt.show()

# %% [markdown]
# 에포크 값을 늘리면 더 좋은 결과가 나올거 같다.
