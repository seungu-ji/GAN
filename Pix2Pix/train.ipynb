# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/pytorch-GAN/Pix2Pix
# Out:
# /content/drive/MyDrive/pytorch-GAN/Pix2Pix

# %%
# !python3 train.py --data_dir '/content/drive/MyDrive/data/facades'
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# TRAIN: EPOCH 0076 / 0200 | BATCH 0001 / 0040 | GEN gan 1.6982 | GEN L1 0.2240 | DISC REAL: 0.5289 | DISC FAKE: 0.3965
# TRAIN: EPOCH 0076 / 0200 | BATCH 0002 / 0040 | GEN gan 1.8113 | GEN L1 0.2382 | DISC REAL: 0.4249 | DISC FAKE: 0.4322
# TRAIN: EPOCH 0076 / 0200 | BATCH 0003 / 0040 | GEN gan 1.7309 | GEN L1 0.2439 | DISC REAL: 0.4395 | DISC FAKE: 0.3405
# TRAIN: EPOCH 0076 / 0200 | BATCH 0004 / 0040 | GEN gan 1.8115 | GEN L1 0.2504 | DISC REAL: 0.3898 | DISC FAKE: 0.5110
# TRAIN: EPOCH 0076 / 0200 | BATCH 0005 / 0040 | GEN gan 1.7255 | GEN L1 0.2478 | DISC REAL: 0.4839 | DISC FAKE: 0.4353
# TRAIN: EPOCH 0076 / 0200 | BATCH 0006 / 0040 | GEN gan 1.6387 | GEN L1 0.2438 | DISC REAL: 0.4652 | DISC FAKE: 0.4376
# TRAIN: EPOCH 0076 / 0200 | BATCH 0007 / 0040 | GEN gan 1.7263 | GEN L1 0.2430 | DISC REAL: 0.4164 | DISC FAKE: 0.4517
# TRAIN: EPOCH 0076 / 0200 | BATCH 0008 / 0040 | GEN gan 1.8002 | GEN L1 0.2435 | DISC REAL: 0.3997 | DISC FAKE: 0.4153
# ...

# %% [markdown]
# 실제 이미지와 생성 이미지 비교해보기

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
 
# input 이미지
img = mpimg.imread('./result/train/png/6660_input.png')

plt.imshow(img)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
 
# Generator가 생성한 이미지
img = mpimg.imread('./result/train/png/6660_output.png')

plt.imshow(img)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
 
# 원본 이미지
img = mpimg.imread('./result/train/png/6660_label.png')

plt.imshow(img)
plt.show()
